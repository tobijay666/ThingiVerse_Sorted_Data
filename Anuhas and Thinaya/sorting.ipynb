# %%
import pandas as pd
import os
import numpy as np
import trimesh

# %% [markdown]
# - Curvature estimation (Gaussian curvature) was tested but removed.
#
# - Reason: curvature metrics were unreliable for STL models with gaps, degenerate faces, or poor mesh quality which produced errors for noisy or incomplete geometry.

# %%
# Simplified curvature estimation that's more robust to degenerate faces
def estimate_gaussian_curvature_robust(mesh):
    try:
        # Try to use trimesh's built-in vertex_faces if available
        vertex_faces = mesh.vertex_faces
        curvature = np.zeros(len(mesh.vertices))
        
        for i in range(len(mesh.vertices)):
            try:
                faces = vertex_faces[i]
                valid_faces = faces[faces != -1]
                
                if len(valid_faces) == 0:
                    curvature[i] = 0
                    continue
                    
                angles = []
                vertex = mesh.vertices[i]
                
                for face_idx in valid_faces:
                    face = mesh.faces[face_idx]
                    # Find position of current vertex in the face
                    vertex_pos = np.where(face == i)[0]
                    if len(vertex_pos) == 0:
                        continue
                        
                    # Get the other two vertices
                    other_indices = face[face != i]
                    if len(other_indices) >= 2:
                        v1, v2 = mesh.vertices[other_indices[:2]]
                        
                        # Calculate vectors from current vertex to others
                        vec1 = v1 - vertex
                        vec2 = v2 - vertex
                        
                        # Calculate angle
                        norm1, norm2 = np.linalg.norm(vec1), np.linalg.norm(vec2)
                        if norm1 > 1e-8 and norm2 > 1e-8:
                            cos_angle = np.clip(np.dot(vec1, vec2) / (norm1 * norm2), -1.0, 1.0)
                            angle = np.arccos(cos_angle)
                            angles.append(angle)
                
                # Calculate curvature using angle deficit
                if len(angles) > 0:
                    angle_sum = np.sum(angles)
                    curvature[i] = (2 * np.pi) - angle_sum
                else:
                    curvature[i] = 0
                    
            except Exception:
                curvature[i] = 0
                
        return curvature
        
    except Exception:
        # Fallback: use a simple geometric measure
        print("Warning: Falling back to simplified curvature estimation")
        return np.zeros(len(mesh.vertices))
# issue was that some models with blannk faces were causing errors

# %% [markdown]
# - Implemented `simple_flatness_analysis`func where it uses height ratio, Z-variation, normal variation, and aspect ratio for flatness detection.
# - Reason: Avoided curvature due to errors on degenerate meshes; improved reliability for noisy STL files. Aspect ratio helps distinguish flat, non-elongated shapes from thin, elongated ones.

# %%
# Alternative simple flatness estimation without vertex_faces
def simple_flatness_analysis(mesh):
    try:
        # Basic geometric metrics
        bounds = mesh.bounds
        dimensions = bounds[1] - bounds[0]
        height_ratio = dimensions[2] / max(dimensions[0], dimensions[1])
        
        # Z-coordinate variation
        z_coords = mesh.vertices[:, 2]
        z_std = np.std(z_coords)
        z_range = np.max(z_coords) - np.min(z_coords)
        z_std_normalized = z_std / z_range if z_range > 0 else 0
        
        # Surface normal variation (simplified)
        try:
            face_normals = mesh.face_normals
            # Calculate how much normals vary (flatness indicator)
            normal_std = np.std(face_normals, axis=0)
            normal_variation = np.mean(normal_std)
        except Exception:
            normal_variation = 0.5  # Default moderate variation
        
        return {
            'height_ratio': height_ratio,
            'z_std_normalized': z_std_normalized,
            'normal_variation': normal_variation,
            'dimensions': dimensions
        }
    except Exception as e:
        raise e

# NEW (fast): quantify how much of the mesh area lies on a few dominant plane orientations
# Vectorized spherical binning of face normals (treat n and -n as same) to avoid O(F^2) clustering
# bin_degrees controls angular bin size; larger bins -> faster and more tolerant grouping

# %% [markdown]
# - Added `planarity_dominance` func to quantify dominant plane orientation using spherical binning of face normals.
# - Reason: Fast, robust way to detect planar surfaces and distinguish flat vs. free-form models.

# %%
def planarity_dominance(mesh, bin_degrees: float = 15.0):
    """
    Fast area-weighted dominance of face-normal orientation.
    Returns fraction of total surface area in the most-populated normal bin.
    Opposite directions are treated as identical (hemisphere mapping).
    """
    try:
        normals = mesh.face_normals
        if normals is None or len(normals) == 0:
            return 0.0
        areas = getattr(mesh, 'area_faces', None)
        if areas is None:
            areas = np.ones(len(normals), dtype=np.float64)
        else:
            areas = areas.astype(np.float64, copy=False)
        # Normalize to unit and map to canonical hemisphere so n and -n coincide
        norms = np.linalg.norm(normals, axis=1)
        normals = normals / (norms[:, None] + 1e-12)
        mask = (normals[:, 0] < 0) | ((normals[:, 0] == 0) & (normals[:, 1] < 0)) | ((normals[:, 0] == 0) & (normals[:, 1] == 0) & (normals[:, 2] < 0))
        normals[mask] = -normals[mask]
        # Spherical coordinates
        theta = np.arccos(np.clip(normals[:, 2], -1.0, 1.0))   # 0..pi
        phi = np.arctan2(normals[:, 1], normals[:, 0])        # -pi..pi
        phi = np.where(phi < 0, phi + 2*np.pi, phi)           # 0..2pi
        d = np.deg2rad(bin_degrees)
        nbins_theta = max(1, int(np.ceil(np.pi / d)))
        nbins_phi = max(1, int(np.ceil(2*np.pi / d)))
        btheta = np.minimum((theta / d).astype(np.int32), nbins_theta - 1)
        bphi = np.minimum((phi / d).astype(np.int32), nbins_phi - 1)
        keys = (btheta.astype(np.int64) * nbins_phi) + bphi.astype(np.int64)
        # Sum areas per bin using sorting + reduceat (vectorized)
        order = np.argsort(keys)
        keys_sorted = keys[order]
        areas_sorted = areas[order]
        uniq, start_idx, counts = np.unique(keys_sorted, return_index=True, return_counts=True)
        bin_sums = np.add.reduceat(areas_sorted, start_idx)
        total_area = float(areas_sorted.sum()) + 1e-12
        return float(bin_sums.max()) / total_area if bin_sums.size else 0.0
    except Exception:
        return 0.0

# %% [markdown]
# Test for a single STL file from the dataset

# %%
data_dir = r'C:\\Users\\Anuhas\\Documents\\Research\\Thingiverse\\data'
stl_files = [f for f in os.listdir(data_dir) if f.endswith('.stl')]

if stl_files:
    # Test with the first available STL file
    test_file = stl_files[0]
    file_path = os.path.join(data_dir, test_file)
    
    print(f"Analyzing: {test_file}")
    
    try:
        mesh = trimesh.load(file_path)
        
        # Use simple analysis first
        simple_analysis = simple_flatness_analysis(mesh)
        print(f"Height ratio: {simple_analysis['height_ratio']:.4f}")
        print(f"Z-variation (normalized): {simple_analysis['z_std_normalized']:.4f}")
        print(f"Normal variation: {simple_analysis['normal_variation']:.4f}")
        # Show new planarity metric
        pd_score = planarity_dominance(mesh)
        print(f"Planarity dominance: {pd_score:.3f}")
        
        print(f"Dimensions: width={simple_analysis['dimensions'][0]:.2f}, depth={simple_analysis['dimensions'][1]:.2f}, height={simple_analysis['dimensions'][2]:.2f}")
        
        # Check criteria
        crit = {
            'planarity_dominant': pd_score >= 0.70,
            'height_ratio_flat': simple_analysis['height_ratio'] < 0.20,
            'z_variation_flat': simple_analysis['z_std_normalized'] < 0.35,
            'normal_variation_flat': simple_analysis['normal_variation'] < 0.35
        }
        votes = sum(crit.values())
        pred = 'FLAT' if (crit['planarity_dominant'] and (crit['z_variation_flat'] or crit['normal_variation_flat'])) or votes >= (len(crit)/2) else 'FREE-FORM'
        print(f"Criteria votes: {votes}/{len(crit)}")
        print(f"Prediction: {pred}")
        
        # Try curvature analysis with robust method
        try:
            curvature = estimate_gaussian_curvature_robust(mesh)
            mean_curvature = np.mean(np.abs(curvature))
            print(f"Mean Gaussian curvature: {mean_curvature:.6f}")
        except Exception as e:
            print(f"Curvature analysis failed: {e}")
            mean_curvature = 0
        
        # Simple classification
        is_flat = (simple_analysis['height_ratio'] < 0.15 and 
                  simple_analysis['z_std_normalized'] < 0.3)
        print(f"Simple prediction: {'FLAT' if is_flat else 'FREE-FORM'}")
        
    except Exception as e:
        print(f"Error loading {test_file}: {e}")
else:
    print("No STL files found in data directory.")
# Out:
# Analyzing: 103742.stl
# Height ratio: 0.0185
# Z-variation (normalized): 0.3536
# Normal variation: 0.5685
# Planarity dominance: 0.247
# Dimensions: width=135.20, depth=99.00, height=2.49
# Criteria votes: 1/4
# Prediction: FREE-FORM
# Mean Gaussian curvature: 0.485749
# Simple prediction: FREE-FORM
# Mean Gaussian curvature: 0.485749
# Simple prediction: FREE-FORM

# %% [markdown]
# Test for all STL files in the dataset and save results to CSV

# %%
from datetime import datetime

# Get all STL files from the data directory
data_dir = r'C:\\Users\\Anuhas\\Documents\\Research\\Thingiverse\\data'
stl_files = [f for f in os.listdir(data_dir) if f.endswith('.stl')]

print(f"Found {len(stl_files)} STL files to analyze...")

# Store results
results = []
processed = 0
errors = 0

# Ensure comprehensive_stl_analysis exists (define minimal wrapper if missing)
if 'comprehensive_stl_analysis' not in globals():
    def comprehensive_stl_analysis(file_path):
        mesh = trimesh.load(file_path)
        sm = simple_flatness_analysis(mesh)
        try:
            pd_score = planarity_dominance(mesh)
        except Exception:
            pd_score = 0.0
        width, depth, height = sm['dimensions']
        aspect_ratio_1 = height / width if width > 0 else 0
        aspect_ratio_2 = height / depth if depth > 0 else 0
        max_ar = max(aspect_ratio_1, aspect_ratio_2)
        crit = {
            'planarity_dominant': pd_score >= 0.70,
            'height_ratio_flat': sm['height_ratio'] < 0.20,
            'z_variation_flat': sm['z_std_normalized'] < 0.35,
            'normal_variation_flat': sm['normal_variation'] < 0.35,
            'aspect_ratio_flat': max_ar < 0.30
        }
        votes = sum(crit.values())
        pred = 'FLAT' if (crit['planarity_dominant'] and (crit['z_variation_flat'] or crit['normal_variation_flat'])) or votes >= (len(crit)/2) else 'FREE-FORM'
        return {
            'filename': os.path.basename(file_path),
            'prediction': pred,
            'height_ratio': sm['height_ratio'],
            'z_std_normalized': sm['z_std_normalized'],
            'normal_variation': sm['normal_variation'],
            'planarity_dominance': pd_score,
            'max_aspect_ratio': max_ar,
            'criteria_votes': votes,
            'total_criteria': len(crit),
            'dimensions': sm['dimensions'].tolist() if hasattr(sm['dimensions'], 'tolist') else list(sm['dimensions'])
        }

for filename in stl_files:
    file_path = os.path.join(data_dir, filename)
    print(f"Processing {processed + 1}/{len(stl_files)}: {filename}")
    
    try:
        result = comprehensive_stl_analysis(file_path)
        if result['prediction'] == 'ERROR':
            errors += 1
            print(f"  ERROR: {result.get('error', 'Unknown error')}")
        else:
            print(f"  Prediction: {result['prediction']} (votes: {result['criteria_votes']}/{result['total_criteria']}, planarity: {result.get('planarity_dominance', 0):.2f})")
        results.append(result)
    except Exception as e:
        errors += 1
        print(f"  ERROR (pipeline): {e}")
    processed += 1

# Convert results to DataFrame
df_results = pd.DataFrame(results)

# Save to CSV with timestamp
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
output_file = f'stl_analysis_results_{timestamp}.csv'
output_path = os.path.join(r'C:\\Users\\Anuhas\\Documents\\Research\\Thingiverse', output_file)

df_results.to_csv(output_path, index=False)

print(f"\n=== ANALYSIS COMPLETE ===")
print(f"Total files processed: {processed}")
print(f"Successful analyses: {processed - errors}")
print(f"Errors: {errors}")
print(f"Results saved to: {output_path}")

# Display summary statistics
if processed > errors:
    predictions = df_results[df_results['prediction'] != 'ERROR']['prediction']
    print(f"\n=== PREDICTION SUMMARY ===")
    print(f"FLAT models: {sum(predictions == 'FLAT')}")
    print(f"FREE-FORM models: {sum(predictions == 'FREE-FORM')}")
    
    # Show first few results (updated column names)
    print(f"\n=== FIRST 5 RESULTS ===")
    display_cols = ['filename', 'prediction', 'planarity_dominance', 'height_ratio', 'z_std_normalized', 'normal_variation', 'max_aspect_ratio']
    print(df_results[display_cols].head())
    
    # Show available columns for reference
    print(f"\n=== ALL AVAILABLE COLUMNS ===")
    print(list(df_results.columns))
# Out:
# Found 249 STL files to analyze...
# Processing 1/249: 103742.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.25)
# Processing 2/249: 103815.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.11)
# Processing 3/249: 103817.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.11)
# Processing 3/249: 103817.stl
# Found 249 STL files to analyze...
# Processing 1/249: 103742.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.25)
# Processing 2/249: 103815.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.11)
# Processing 3/249: 103817.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.11)
# Processing 3/249: 103817.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.10)
# Processing 4/249: 103821.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.32)
# Processing 5/249: 103824.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.46)
# Processing 6/249: 103825.stl
#
# Processing 4/249: 103821.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.32)
# Processing 5/249: 103824.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.46)
# Processing 6/249: 103825.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.46)
# Processing 7/249: 103826.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.46)
# Processing 8/249: 104187.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.46)
# Processing 7/249: 103826.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.46)
# Processing 8/249: 104187.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.32)
# Processing 9/249: 104188.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.33)
# Processing 10/249: 104290.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.32)
# Processing 9/249: 104188.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.33)
# Processing 10/249: 104290.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.34)
# Processing 11/249: 104294.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.33)
# Processing 12/249: 104301.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.23)
# Processing 13/249: 104400.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.34)
# Processing 11/249: 104294.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.33)
# Processing 12/249: 104301.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.23)
# Processing 13/249: 104400.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.31)
# Processing 14/249: 104401.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.30)
# Processing 15/249: 104402.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.27)
# Processing 16/249: 104403.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.31)
# Processing 14/249: 104401.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.30)
# Processing 15/249: 104402.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.27)
# Processing 16/249: 104403.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.40)
# Processing 17/249: 104404.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.24)
# Processing 18/249: 104421.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.32)
# Processing 19/249: 104431.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.24)
# Processing 20/249: 104432.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.40)
# Processing 17/249: 104404.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.24)
# Processing 18/249: 104421.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.32)
# Processing 19/249: 104431.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.24)
# Processing 20/249: 104432.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.33)
# Processing 21/249: 104442.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.33)
# Processing 21/249: 104442.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.11)
# Processing 22/249: 104445.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.29)
# Processing 23/249: 104509.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.11)
# Processing 22/249: 104445.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.29)
# Processing 23/249: 104509.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.31)
# Processing 24/249: 104510.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.38)
# Processing 25/249: 104511.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.31)
# Processing 24/249: 104510.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.38)
# Processing 25/249: 104511.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.45)
# Processing 26/249: 104512.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.37)
# Processing 27/249: 104513.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.47)
# Processing 28/249: 104559.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.45)
# Processing 26/249: 104512.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.37)
# Processing 27/249: 104513.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.47)
# Processing 28/249: 104559.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.04)
# Processing 29/249: 104563.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.22)
# Processing 30/249: 104582.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.04)
# Processing 29/249: 104563.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.22)
# Processing 30/249: 104582.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.37)
# Processing 31/249: 104606.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.37)
# Processing 31/249: 104606.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.13)
# Processing 32/249: 104639.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.20)
# Processing 33/249: 104640.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.10)
# Processing 34/249: 104737.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.27)
# Processing 35/249: 104738.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.13)
# Processing 32/249: 104639.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.20)
# Processing 33/249: 104640.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.10)
# Processing 34/249: 104737.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.27)
# Processing 35/249: 104738.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.20)
# Processing 36/249: 104787.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.20)
# Processing 36/249: 104787.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.19)
# Processing 37/249: 104930.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.46)
# Processing 38/249: 104968.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.23)
# Processing 39/249: 104969.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.19)
# Processing 37/249: 104930.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.46)
# Processing 38/249: 104968.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.23)
# Processing 39/249: 104969.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.04)
# Processing 40/249: 105103.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.26)
# Processing 41/249: 105120.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.10)
# Processing 42/249: 105171.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.31)
# Processing 43/249: 105174.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.04)
# Processing 40/249: 105103.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.26)
# Processing 41/249: 105120.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.10)
# Processing 42/249: 105171.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.31)
# Processing 43/249: 105174.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.21)
# Processing 44/249: 105220.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.22)
# Processing 45/249: 105226.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.20)
# Processing 46/249: 105230.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.15)
# Processing 47/249: 105326.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.21)
# Processing 44/249: 105220.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.22)
# Processing 45/249: 105226.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.20)
# Processing 46/249: 105230.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.15)
# Processing 47/249: 105326.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.12)
# Processing 48/249: 105330.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.35)
# Processing 49/249: 105335.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.12)
# Processing 48/249: 105330.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.35)
# Processing 49/249: 105335.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.17)
# Processing 50/249: 137749.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.21)
# Processing 51/249: 32770.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.17)
# Processing 50/249: 137749.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.21)
# Processing 51/249: 32770.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.13)
# Processing 52/249: 34783.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.10)
# Processing 53/249: 34784.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.13)
# Processing 52/249: 34783.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.10)
# Processing 53/249: 34784.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.10)
# Processing 54/249: 34785.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.08)
# Processing 55/249: 35269.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.10)
# Processing 54/249: 34785.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.08)
# Processing 55/249: 35269.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.21)
# Processing 56/249: 36069.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.29)
# Processing 57/249: 36075.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.30)
# Processing 58/249: 36082.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.26)
# Processing 59/249: 36086.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.22)
# Processing 60/249: 36088.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.28)
# Processing 61/249: 36090.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.22)
# Processing 62/249: 36091.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.21)
# Processing 63/249: 36092.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.22)
# Processing 64/249: 36371.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.21)
# Processing 56/249: 36069.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.29)
# Processing 57/249: 36075.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.30)
# Processing 58/249: 36082.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.26)
# Processing 59/249: 36086.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.22)
# Processing 60/249: 36088.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.28)
# Processing 61/249: 36090.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.22)
# Processing 62/249: 36091.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.21)
# Processing 63/249: 36092.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.22)
# Processing 64/249: 36371.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.21)
# Processing 65/249: 36372.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.31)
# Processing 66/249: 36373.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.22)
# Processing 67/249: 36374.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.20)
# Processing 68/249: 37003.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.21)
# Processing 65/249: 36372.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.31)
# Processing 66/249: 36373.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.22)
# Processing 67/249: 36374.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.20)
# Processing 68/249: 37003.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.15)
# Processing 69/249: 37004.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.13)
# Processing 70/249: 37009.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.15)
# Processing 69/249: 37004.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.13)
# Processing 70/249: 37009.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.05)
# Processing 71/249: 37010.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.12)
# Processing 72/249: 37011.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.05)
# Processing 71/249: 37010.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.12)
# Processing 72/249: 37011.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.14)
# Processing 73/249: 37012.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.31)
# Processing 74/249: 37065.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.22)
# Processing 75/249: 37091.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.19)
# Processing 76/249: 37093.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.22)
# Processing 77/249: 37095.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.42)
# Processing 78/249: 37111.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.14)
# Processing 73/249: 37012.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.31)
# Processing 74/249: 37065.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.22)
# Processing 75/249: 37091.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.19)
# Processing 76/249: 37093.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.22)
# Processing 77/249: 37095.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.42)
# Processing 78/249: 37111.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.05)
# Processing 79/249: 37137.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.05)
# Processing 79/249: 37137.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.22)
# Processing 80/249: 37179.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.17)
# Processing 81/249: 37211.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.33)
# Processing 82/249: 37213.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.39)
# Processing 83/249: 37215.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.33)
# Processing 84/249: 37217.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.22)
# Processing 80/249: 37179.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.17)
# Processing 81/249: 37211.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.33)
# Processing 82/249: 37213.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.39)
# Processing 83/249: 37215.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.33)
# Processing 84/249: 37217.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.22)
# Processing 85/249: 37219.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.26)
# Processing 86/249: 37221.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.29)
# Processing 87/249: 37223.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.31)
# Processing 88/249: 37225.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.34)
# Processing 89/249: 37227.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.22)
# Processing 85/249: 37219.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.26)
# Processing 86/249: 37221.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.29)
# Processing 87/249: 37223.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.31)
# Processing 88/249: 37225.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.34)
# Processing 89/249: 37227.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.27)
# Processing 90/249: 37229.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.42)
# Processing 91/249: 37266.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.27)
# Processing 90/249: 37229.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.42)
# Processing 91/249: 37266.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.02)
# Processing 92/249: 37267.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.02)
# Processing 92/249: 37267.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.03)
# Processing 93/249: 37272.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.14)
# Processing 94/249: 37274.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.28)
# Processing 95/249: 37275.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.03)
# Processing 93/249: 37272.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.14)
# Processing 94/249: 37274.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.28)
# Processing 95/249: 37275.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.34)
# Processing 96/249: 37276.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.25)
# Processing 97/249: 37278.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.46)
# Processing 98/249: 37280.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.47)
# Processing 99/249: 37282.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.20)
# Processing 100/249: 37283.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.35)
# Processing 101/249: 37284.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.34)
# Processing 96/249: 37276.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.25)
# Processing 97/249: 37278.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.46)
# Processing 98/249: 37280.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.47)
# Processing 99/249: 37282.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.20)
# Processing 100/249: 37283.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.35)
# Processing 101/249: 37284.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.27)
# Processing 102/249: 37285.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.16)
# Processing 103/249: 37286.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.68)
# Processing 104/249: 37287.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.45)
# Processing 105/249: 37288.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.27)
# Processing 102/249: 37285.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.16)
# Processing 103/249: 37286.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.68)
# Processing 104/249: 37287.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.45)
# Processing 105/249: 37288.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.17)
# Processing 106/249: 37289.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.26)
# Processing 107/249: 37303.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.29)
# Processing 108/249: 37304.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.27)
# Processing 109/249: 37322.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.17)
# Processing 106/249: 37289.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.26)
# Processing 107/249: 37303.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.29)
# Processing 108/249: 37304.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.27)
# Processing 109/249: 37322.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.15)
# Processing 110/249: 37323.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.11)
# Processing 111/249: 37325.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.13)
# Processing 112/249: 37326.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.11)
# Processing 113/249: 37327.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.12)
# Processing 114/249: 37328.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.15)
# Processing 110/249: 37323.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.11)
# Processing 111/249: 37325.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.13)
# Processing 112/249: 37326.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.11)
# Processing 113/249: 37327.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.12)
# Processing 114/249: 37328.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.11)
# Processing 115/249: 37329.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.10)
# Processing 116/249: 37330.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.11)
# Processing 117/249: 37331.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.14)
# Processing 118/249: 37332.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.08)
# Processing 119/249: 37335.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.11)
# Processing 115/249: 37329.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.10)
# Processing 116/249: 37330.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.11)
# Processing 117/249: 37331.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.14)
# Processing 118/249: 37332.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.08)
# Processing 119/249: 37335.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.10)
# Processing 120/249: 37358.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.10)
# Processing 120/249: 37358.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.02)
# Processing 121/249: 37361.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.02)
# Processing 121/249: 37361.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.15)
# Processing 122/249: 37365.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.24)
# Processing 123/249: 37366.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.15)
# Processing 124/249: 37384.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.04)
# Processing 125/249: 37402.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.03)
# Processing 126/249: 37404.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.15)
# Processing 122/249: 37365.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.24)
# Processing 123/249: 37366.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.15)
# Processing 124/249: 37384.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.04)
# Processing 125/249: 37402.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.03)
# Processing 126/249: 37404.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.46)
# Processing 127/249: 37415.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.03)
# Processing 128/249: 37416.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.07)
# Processing 129/249: 37506.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.14)
# Processing 130/249: 37568.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.43)
# Processing 131/249: 37569.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.46)
# Processing 127/249: 37415.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.03)
# Processing 128/249: 37416.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.07)
# Processing 129/249: 37506.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.14)
# Processing 130/249: 37568.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.43)
# Processing 131/249: 37569.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.12)
# Processing 132/249: 37620.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.37)
# Processing 133/249: 37621.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.24)
# Processing 134/249: 37622.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.48)
# Processing 135/249: 37627.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.35)
# Processing 136/249: 37653.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.12)
# Processing 132/249: 37620.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.37)
# Processing 133/249: 37621.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.24)
# Processing 134/249: 37622.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.48)
# Processing 135/249: 37627.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.35)
# Processing 136/249: 37653.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.15)
# Processing 137/249: 37730.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.13)
# Processing 138/249: 37731.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.15)
# Processing 137/249: 37730.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.13)
# Processing 138/249: 37731.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.09)
# Processing 139/249: 37743.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.37)
# Processing 140/249: 37744.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.39)
# Processing 141/249: 37745.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.38)
# Processing 142/249: 37746.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.37)
# Processing 143/249: 37747.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.36)
# Processing 144/249: 37748.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.09)
# Processing 139/249: 37743.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.37)
# Processing 140/249: 37744.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.39)
# Processing 141/249: 37745.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.38)
# Processing 142/249: 37746.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.37)
# Processing 143/249: 37747.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.36)
# Processing 144/249: 37748.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.16)
# Processing 145/249: 37750.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.18)
# Processing 146/249: 37751.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.16)
# Processing 147/249: 37765.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.05)
# Processing 148/249: 37766.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.04)
# Processing 149/249: 37772.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.16)
# Processing 145/249: 37750.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.18)
# Processing 146/249: 37751.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.16)
# Processing 147/249: 37765.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.05)
# Processing 148/249: 37766.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.04)
# Processing 149/249: 37772.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.11)
# Processing 150/249: 38157.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.05)
# Processing 151/249: 38261.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.11)
# Processing 150/249: 38157.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.05)
# Processing 151/249: 38261.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.48)
# Processing 152/249: 38290.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.10)
# Processing 153/249: 38291.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.10)
# Processing 154/249: 38292.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.11)
# Processing 155/249: 38293.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.11)
# Processing 156/249: 38294.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.13)
# Processing 157/249: 38295.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.10)
# Processing 158/249: 38296.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.12)
# Processing 159/249: 38297.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.48)
# Processing 152/249: 38290.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.10)
# Processing 153/249: 38291.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.10)
# Processing 154/249: 38292.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.11)
# Processing 155/249: 38293.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.11)
# Processing 156/249: 38294.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.13)
# Processing 157/249: 38295.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.10)
# Processing 158/249: 38296.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.12)
# Processing 159/249: 38297.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.11)
# Processing 160/249: 38318.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.05)
# Processing 161/249: 38416.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.11)
# Processing 160/249: 38318.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.05)
# Processing 161/249: 38416.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.23)
# Processing 162/249: 38464.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.50)
# Processing 163/249: 38465.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.44)
# Processing 164/249: 38492.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.12)
# Processing 165/249: 38493.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.04)
# Processing 166/249: 38494.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.23)
# Processing 162/249: 38464.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.50)
# Processing 163/249: 38465.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.44)
# Processing 164/249: 38492.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.12)
# Processing 165/249: 38493.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.04)
# Processing 166/249: 38494.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.07)
# Processing 167/249: 38495.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.10)
# Processing 168/249: 38496.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.07)
# Processing 169/249: 38497.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.30)
# Processing 170/249: 38498.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.07)
# Processing 167/249: 38495.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.10)
# Processing 168/249: 38496.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.07)
# Processing 169/249: 38497.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.30)
# Processing 170/249: 38498.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.06)
# Processing 171/249: 38554.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.06)
# Processing 171/249: 38554.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.17)
# Processing 172/249: 38557.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.27)
# Processing 173/249: 38558.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.17)
# Processing 172/249: 38557.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.27)
# Processing 173/249: 38558.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.22)
# Processing 174/249: 38559.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.16)
# Processing 175/249: 38562.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.22)
# Processing 174/249: 38559.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.16)
# Processing 175/249: 38562.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.14)
# Processing 176/249: 38564.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.40)
# Processing 177/249: 38631.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.14)
# Processing 176/249: 38564.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.40)
# Processing 177/249: 38631.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.05)
# Processing 178/249: 38635.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.24)
# Processing 179/249: 38636.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.05)
# Processing 178/249: 38635.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.24)
# Processing 179/249: 38636.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.24)
# Processing 180/249: 38637.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.33)
# Processing 181/249: 38638.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.12)
# Processing 182/249: 38639.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.19)
# Processing 183/249: 38640.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.23)
# Processing 184/249: 38641.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.46)
# Processing 185/249: 38642.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.24)
# Processing 180/249: 38637.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.33)
# Processing 181/249: 38638.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.12)
# Processing 182/249: 38639.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.19)
# Processing 183/249: 38640.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.23)
# Processing 184/249: 38641.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.46)
# Processing 185/249: 38642.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.38)
# Processing 186/249: 38643.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.11)
# Processing 187/249: 38644.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.21)
# Processing 188/249: 38645.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.25)
# Processing 189/249: 38646.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.38)
# Processing 186/249: 38643.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.11)
# Processing 187/249: 38644.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.21)
# Processing 188/249: 38645.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.25)
# Processing 189/249: 38646.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.12)
# Processing 190/249: 38741.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.31)
# Processing 191/249: 38753.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.45)
# Processing 192/249: 38781.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.20)
# Processing 193/249: 39009.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.24)
# Processing 194/249: 39010.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.29)
# Processing 195/249: 39011.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.12)
# Processing 190/249: 38741.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.31)
# Processing 191/249: 38753.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.45)
# Processing 192/249: 38781.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.20)
# Processing 193/249: 39009.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.24)
# Processing 194/249: 39010.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.29)
# Processing 195/249: 39011.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.30)
# Processing 196/249: 39012.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.06)
# Processing 197/249: 39025.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.13)
# Processing 198/249: 39026.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.18)
# Processing 199/249: 39027.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.10)
# Processing 200/249: 40660.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.30)
# Processing 196/249: 39012.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.06)
# Processing 197/249: 39025.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.13)
# Processing 198/249: 39026.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.18)
# Processing 199/249: 39027.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.10)
# Processing 200/249: 40660.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.23)
# Processing 201/249: 40661.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.31)
# Processing 202/249: 40662.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.38)
# Processing 203/249: 40663.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.24)
# Processing 204/249: 40666.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.18)
# Processing 205/249: 40741.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.22)
# Processing 206/249: 40746.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.23)
# Processing 201/249: 40661.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.31)
# Processing 202/249: 40662.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.38)
# Processing 203/249: 40663.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.24)
# Processing 204/249: 40666.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.18)
# Processing 205/249: 40741.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.22)
# Processing 206/249: 40746.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.05)
# Processing 207/249: 40835.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.05)
# Processing 208/249: 40836.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.28)
# Processing 209/249: 40842.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.29)
# Processing 210/249: 40843.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.44)
# Processing 211/249: 40844.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.40)
# Processing 212/249: 40845.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.40)
# Processing 213/249: 40847.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.39)
# Processing 214/249: 40876.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.15)
# Processing 215/249: 40886.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.05)
# Processing 207/249: 40835.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.05)
# Processing 208/249: 40836.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.28)
# Processing 209/249: 40842.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.29)
# Processing 210/249: 40843.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.44)
# Processing 211/249: 40844.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.40)
# Processing 212/249: 40845.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.40)
# Processing 213/249: 40847.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.39)
# Processing 214/249: 40876.stl
#   Prediction: FREE-FORM (votes: 0/4, planarity: 0.15)
# Processing 215/249: 40886.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.04)
# Processing 216/249: 40888.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.04)
# Processing 216/249: 40888.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.01)
# Processing 217/249: 40892.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.18)
# Processing 218/249: 40893.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.23)
# Processing 219/249: 40900.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.01)
# Processing 217/249: 40892.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.18)
# Processing 218/249: 40893.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.23)
# Processing 219/249: 40900.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.15)
# Processing 220/249: 40906.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.18)
# Processing 221/249: 40915.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.34)
# Processing 222/249: 40920.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.29)
# Processing 223/249: 40921.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.39)
# Processing 224/249: 40923.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.15)
# Processing 220/249: 40906.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.18)
# Processing 221/249: 40915.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.34)
# Processing 222/249: 40920.stl
#   Prediction: FLAT (votes: 2/4, planarity: 0.29)
# Processing 223/249: 40921.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.39)
# Processing 224/249: 40923.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.12)
# Processing 225/249: 40926.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.08)
# Processing 226/249: 40982.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.12)
# Processing 225/249: 40926.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.08)
# Processing 226/249: 40982.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.04)
# Processing 227/249: 40984.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.10)
# Processing 228/249: 40985.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.07)
# Processing 229/249: 40987.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.02)
# Processing 230/249: 40991.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.04)
# Processing 227/249: 40984.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.10)
# Processing 228/249: 40985.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.07)
# Processing 229/249: 40987.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.02)
# Processing 230/249: 40991.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.04)
# Processing 231/249: 40992.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.04)
# Processing 232/249: 40993.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.04)
# Processing 231/249: 40992.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.04)
# Processing 232/249: 40993.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.14)
# Processing 233/249: 40994.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.05)
# Processing 234/249: 41077.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.14)
# Processing 233/249: 40994.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.05)
# Processing 234/249: 41077.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.28)
# Processing 235/249: 41079.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.29)
# Processing 236/249: 41080.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.28)
# Processing 235/249: 41079.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.29)
# Processing 236/249: 41080.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.27)
# Processing 237/249: 41081.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.25)
# Processing 238/249: 41082.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.27)
# Processing 237/249: 41081.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.25)
# Processing 238/249: 41082.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.24)
# Processing 239/249: 41083.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.24)
# Processing 240/249: 41084.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.28)
# Processing 241/249: 41085.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.24)
# Processing 239/249: 41083.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.24)
# Processing 240/249: 41084.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.28)
# Processing 241/249: 41085.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.36)
# Processing 242/249: 41086.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.33)
# Processing 243/249: 41087.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.36)
# Processing 242/249: 41086.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.33)
# Processing 243/249: 41087.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.20)
# Processing 244/249: 41089.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.24)
# Processing 245/249: 41090.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.26)
# Processing 246/249: 41092.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.20)
# Processing 244/249: 41089.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.24)
# Processing 245/249: 41090.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.26)
# Processing 246/249: 41092.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.23)
# Processing 247/249: 41104.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.14)
# Processing 248/249: 41105.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.14)
# Processing 249/249: 41106.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.19)
#
# === ANALYSIS COMPLETE ===
# Total files processed: 249
# Successful analyses: 249
# Errors: 0
# Results saved to: C:\\Users\\Anuhas\\Documents\\Research\\Thingiverse\stl_analysis_results_20250901_201443.csv
#
# === PREDICTION SUMMARY ===
# FLAT models: 28
# FREE-FORM models: 221
#
# === FIRST 5 RESULTS ===
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.23)
# Processing 247/249: 41104.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.14)
# Processing 248/249: 41105.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.14)
# Processing 249/249: 41106.stl
#   Prediction: FREE-FORM (votes: 1/4, planarity: 0.19)
#
# === ANALYSIS COMPLETE ===
# Total files processed: 249
# Successful analyses: 249
# Errors: 0
# Results saved to: C:\\Users\\Anuhas\\Documents\\Research\\Thingiverse\stl_analysis_results_20250901_201443.csv
#
# === PREDICTION SUMMARY ===
# FLAT models: 28
# FREE-FORM models: 221
#
# === FIRST 5 RESULTS ===
#      filename prediction  planarity_dominance  height_ratio  z_std_normalized  \
# 0  103742.stl  FREE-FORM             0.247247      0.018450          0.353606
# 1  103815.stl       FLAT             0.111542      0.077679          0.215609
# 2  103817.stl  FREE-FORM             0.103519      0.642136          0.458389
# 3  103821.stl  FREE-FORM             0.319469      1.900000          0.320453
# 4  103824.stl  FREE-FORM             0.460643      3.251029          0.371355
#
#    normal_variation
# 0          0.568530
# 1          0.563018
# 2          0.520643
# 3          0.561457
# 4          0.562503
#
# === ALL AVAILABLE COLUMNS ===
# ['filename', 'prediction', 'height_ratio', 'z_std_normalized', 'normal_variation', 'planarity_dominance', 'criteria_votes', 'total_criteria', 'dimensions']
#      filename prediction  planarity_dominance  height_ratio  z_std_normalized  \
# 0  103742.stl  FREE-FORM             0.247247      0.018450          0.353606
# 1  103815.stl       FLAT             0.111542      0.077679          0.215609
# 2  103817.stl  FREE-FORM             0.103519      0.642136          0.458389
# 3  103821.stl  FREE-FORM             0.319469      1.900000          0.320453
# 4  103824.stl  FREE-FORM             0.460643      3.251029          0.371355
#
#    normal_variation
# 0          0.568530
# 1          0.563018
# 2          0.520643
# 3          0.561457
# 4          0.562503
#
# === ALL AVAILABLE COLUMNS ===
# ['filename', 'prediction', 'height_ratio', 'z_std_normalized', 'normal_variation', 'planarity_dominance', 'criteria_votes', 'total_criteria', 'dimensions']
